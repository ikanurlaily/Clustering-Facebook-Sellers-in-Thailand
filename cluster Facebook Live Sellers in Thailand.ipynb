# %% [markdown]
# # Facebook Live Sellers in Thailand Sellers

# %% [markdown]
# ##### BACKGROUND
#
# Facebook Live has recently become a popular direct selling medium, notably in East and South-East Asia. This feature offers small, self-employed sellers unseen level of consumer reach and involvement and is reinventing direct selling. This study applied data analytics to social network dataset extracted from Facebook to explore user behaviours and effectiveness of Facebook live as a direct selling tool. The  results  affirm  the  strong  impact  that  Facebook  Live  usage  has  had  on  the  patterns,  statistical  structure and extent of consumer engagement as well as the virality of posts. Specifically, live videos generate more comments, emotional reaction, share, and time exposure suggesting higher cognitive, affective,  and  behavioural  engagement  with  sellers,  relative  to  other  types  of  Facebook  posts.  Implications and future research are also briefly discussed.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import Data

# %%
data= pd.read_csv('livefix.csv')

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#                               status_id  status_published status_type  \
# 0      246675545449582_1649696485147474    4/22/2018 6:00       video
# 1      246675545449582_1649426988507757   4/21/2018 22:45       photo
# 2      246675545449582_1648730588577397    4/21/2018 6:17       video
# 3      246675545449582_1648576705259452    4/21/2018 2:29       photo
# 4      246675545449582_1645700502213739    4/18/2018 3:22       photo
# 5      246675545449582_1645650162218773    4/18/2018 2:14       photo
# 6      246675545449582_1645564175560705    4/18/2018 0:24       video
# 7      246675545449582_1644824665634656    4/17/2018 7:42       video
# 8      246675545449582_1644655795651543    4/17/2018 3:33       photo
# 9      246675545449582_1638788379571618     04-11-18 4:53       photo
# 10     246675545449582_1637655039684952     04-10-18 1:01       photo
# 11     246675545449582_1636730006444122     04-09-18 2:06       photo
# ...

# %% [markdown]
# ## Pre processing Data

# %%
data = data.iloc[:,2:12]

# %%
data
# Out:
#      status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0          video            529           512         262        432
# 1          photo            150             0           0        150
# 2          video            227           236          57        204
# 3          photo            111             0           0        111
# 4          photo            213             0           0        204
# 5          photo            217             6           0        211
# 6          video            503           614          72        418
# 7          video            295           453          53        260
# 8          photo            203             1           0        198
# 9          photo            170             9           1        167
# 10         photo            210             2           3        202
# 11         photo            222             4           0        213
# 12         photo            313             4           2        305
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 10 columns):
# status_type      7050 non-null object
# num_reactions    7050 non-null int64
# num_comments     7050 non-null int64
# num_shares       7050 non-null int64
# num_likes        7050 non-null int64
# num_loves        7050 non-null int64
# num_wows         7050 non-null int64
# num_hahas        7050 non-null int64
# num_sads         7050 non-null int64
# num_angrys       7050 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 550.9+ KB

# %%
np.sum(data.isnull())
# Out:
# status_type      0
# num_reactions    0
# num_comments     0
# num_shares       0
# num_likes        0
# num_loves        0
# num_wows         0
# num_hahas        0
# num_sads         0
# num_angrys       0
# dtype: int64

# %%
data.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    7050.000000   7050.000000  7050.000000  7050.000000  7050.000000
# mean      230.117163    224.356028    40.022553   215.043121    12.728652
# std       462.625309    889.636820   131.599965   449.472357    39.972930
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        17.000000      0.000000     0.000000    17.000000     0.000000
# 50%        59.500000      4.000000     0.000000    58.000000     0.000000
# 75%       219.000000     23.000000     4.000000   184.750000     3.000000
# max      4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#           num_wows    num_hahas     num_sads   num_angrys
# count  7050.000000  7050.000000  7050.000000  7050.000000
# mean      1.289362     0.696454     0.243688     0.113191
# std       8.719650     3.957183     1.597156     0.726812
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
data2 = pd.read_csv('live2.csv')

# %%
data2.head()
# Out:
#                           status_id  status_type  num_reactions  num_comments  \
# 0  246675545449582_1649696485147474            4            529           512
# 1  246675545449582_1649426988507757            2            150             0
# 2  246675545449582_1648730588577397            4            227           236
# 3  246675545449582_1648576705259452            2            111             0
# 4  246675545449582_1645700502213739            2            213             0
#
#    num_shares  num_likes  num_loves  num_wows  num_hahas  num_sads  num_angrys
# 0         262        432         92         3          1         1           0
# 1           0        150          0         0          0         0           0
# 2          57        204         21         1          1         0           0
# 3           0        111          0         0          0         0           0
# 4           0        204          9         0          0         0           0

# %%
dataclus=data2.iloc[:,1:12]

# %%
dataclus
# Out:
#       status_type  num_reactions  num_comments  num_shares  num_likes  \
# 0               4            529           512         262        432
# 1               2            150             0           0        150
# 2               4            227           236          57        204
# 3               2            111             0           0        111
# 4               2            213             0           0        204
# 5               2            217             6           0        211
# 6               4            503           614          72        418
# 7               4            295           453          53        260
# 8               2            203             1           0        198
# 9               2            170             9           1        167
# 10              2            210             2           3        202
# 11              2            222             4           0        213
# ...

# %%
dataclus.describe()
# Out:
#        status_type  num_reactions  num_comments   num_shares    num_likes  \
# count  7050.000000    7050.000000   7050.000000  7050.000000  7050.000000
# mean      2.704965     230.117163    224.356028    40.022553   215.043121
# std       0.942399     462.625309    889.636820   131.599965   449.472357
# min       1.000000       0.000000      0.000000     0.000000     0.000000
# 25%       2.000000      17.000000      0.000000     0.000000    17.000000
# 50%       2.000000      59.500000      4.000000     0.000000    58.000000
# 75%       4.000000     219.000000     23.000000     4.000000   184.750000
# max       4.000000    4710.000000  20990.000000  3424.000000  4710.000000
#
#          num_loves     num_wows    num_hahas     num_sads   num_angrys
# count  7050.000000  7050.000000  7050.000000  7050.000000  7050.000000
# mean     12.728652     1.289362     0.696454     0.243688     0.113191
# std      39.972930     8.719650     3.957183     1.597156     0.726812
# ...

# %% [markdown]
# # Visualisasi Data

# %%
reac = dataclus["num_reactions"]

# %%
reac.head()
# Out:
# 0    529
# 1    150
# 2    227
# 3    111
# 4    213
# Name: num_reactions, dtype: int64

# %%
like = dataclus["num_likes"]

# %%
plt.scatter(reac,like, label = 'True Position')
plt.xlabel("Reaction")
plt.ylabel("Likes")
plt.title("REACTION VS LIKES")
# Out:
# Text(0.5,1,'REACTION VS LIKES')

# %%
com = dataclus["num_comments"]
love = dataclus["num_loves"]

# %%
plt.scatter(com,love, label = 'True Position', color='r')
plt.xlabel("Comments")
plt.ylabel("Loves")
plt.title("COMMENTS VS LOVES")
# Out:
# Text(0.5,1,'COMMENTS VS LOVES')

# %%
f,ax=plt.subplots(2,2,figsize=(8,8))
ax[0,0].set_title('Number of Reactions')
data['num_reactions'].hist(figsize=(18,8),color='b', ax=ax[0,0])
pd.DataFrame.skew(data['num_reactions'])
ax[0,1].set_title('Number of Comments')
data['num_comments'].hist(figsize=(18,8),color='g', ax=ax[0,1])
pd.DataFrame.skew(data['num_comments'])
ax[1,0].set_title('Number of Shares')
data['num_shares'].hist(figsize=(18,8),color='y', ax=ax[1,0])
pd.DataFrame.skew(data['num_shares'])
ax[1,1].set_title('Number of Likes')
data['num_likes'].hist(figsize=(18,8),color='black', ax=ax[1,1])
pd.DataFrame.skew(data['num_likes'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
f,ax=plt.subplots(1,figsize=(8,8))
sns.countplot('status_type',data=data)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Correlation Matrix with Heatmap
import pandas as pd
import numpy as np
import seaborn as sns

corrmat = dataclus.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
#plot heat map
g=sns.heatmap(dataclus[top_corr_features].corr(),annot=True,cmap="RdYlGn", linecolor = 'black')

# %% [markdown]
# ## Feature Selection

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
X= dataclus.iloc[:,1:12]
y = dataclus.iloc[:,-1]
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(12).plot(kind='barh')
plt.show()
# Out:
# C:\Users\Windows 10\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [0.01749777 0.01533193 0.08112503 0.01590458 0.09982474 0.01762506
#  0.01875272 0.01855955 0.71537861]

# %% [markdown]
# # Clustering

# %%
#Hierarchical clustering ward
# %matplotlib inline 
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch

# %%
X = np.asarray(dataclus)

# %%
plt.figure(figsize=(10,10))
dendrogram = sch.dendrogram(sch.linkage(X, method='ward'))

# %%
# Melakukan fitting hierarchical clustering 
model = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
model.fit(X)
labels = model.labels_

# %%
labels
# Out:
# array([2, 2, 2, ..., 2, 2, 2], dtype=int64)

# %%
silhouette_score(X, labels, metric='euclidean')
# Out:
# 0.7728664300186489

# %% [markdown]
# ## COMPLETE LINKAGE

# %%
plt.figure(figsize=(100,100))
dendrogram = sch.dendrogram(sch.linkage(X, method='complete'))

# %%
# Melakukan fitting hierarchical clustering 
model = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='complete')
model.fit(X)
labels = model.labels_

# %%
labels
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
silhouette_score(X, labels, metric='euclidean')
# Out:
# 0.8909979405563545

# %% [markdown]
# ## Single Linkage

# %%
plt.figure(figsize=(10,10))
dendrogram = sch.dendrogram(sch.linkage(X, method='single'))

# %%
# Melakukan fitting hierarchical clustering 
model = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='single')
model.fit(X)
labels = model.labels_

# %%
labels
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
silhouette_score(X, labels, metric='euclidean')
# Out:
# 0.9541318929304318

# %% [markdown]
# ## average

# %%
plt.figure(figsize=(10,10))
dendrogram = sch.dendrogram(sch.linkage(X, method='average'))

# %%
# Melakukan fitting hierarchical clustering 
model = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='average')
model.fit(X)
labels = model.labels_

# %%
labels
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
silhouette_score(X, labels, metric='euclidean')
# Out:
# 0.9173647500374776

# %% [markdown]
# # K-means

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
X = np.asarray(dataclus)

# %%
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(X)
    Sum_of_squared_distances.append(km.inertia_)

plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
# Step 5. Melakukan aktivasi algoritma K-Means 
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[2.63900811e+00 1.09817040e+02 7.15077094e+01 1.85261485e+01
#   1.01848037e+02 6.82912097e+00 5.57304085e-01 3.45255126e-01
#   1.66746145e-01 6.75568272e-02]
#  [4.00000000e+00 5.20505415e+02 2.38114440e+03 4.05079422e+02
#   3.95884477e+02 1.07075812e+02 9.02166065e+00 6.15162455e+00
#   1.56678700e+00 8.05054152e-01]
#  [3.96153846e+00 6.38653846e+02 7.76728846e+03 5.79557692e+02
#   4.91519231e+02 1.27423077e+02 5.88461538e+00 9.21153846e+00
#   3.38461538e+00 1.23076923e+00]
#  [2.68372093e+00 1.75366744e+03 1.59020930e+02 5.41093023e+01
#   1.72118372e+03 2.43930233e+01 6.46279070e+00 1.29069767e+00
#   1.37209302e-01 2.00000000e-01]]

# %%
print(kmeans.labels_)
# Out:
# [0 0 0 ... 0 0 0]

# %%
silhouette_samples(X, kmeans.labels_, metric='euclidean')
# Out:
# array([0.58504948, 0.8988328 , 0.83931039, ..., 0.92206048, 0.78831767,
#        0.92669556])

# %%
silhouette_score(X, kmeans.labels_, metric='euclidean')
# Out:
# 0.8167245146928783
